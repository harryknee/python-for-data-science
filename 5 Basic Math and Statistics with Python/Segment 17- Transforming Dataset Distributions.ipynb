# %%
import pandas as pd
import numpy as np
import scipy

import matplotlib.pyplot as plt
import seaborn as sb
from pylab import rcParams

import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import scale

# %% [markdown]
# Two ways to scale data:
# - Normalisation: relative scale of 0 to 1
# - Standardisation: rescale to zero mean and unit variance

# %%
address = 'C:/Users/zxgsh/Desktop/DS/mtcars.csv'

cars = pd.read_csv(address)

# %%
mpg = cars.mpg
plt.plot(mpg)

# %%
cars[ ['mpg'] ].describe()
# Out:
#              mpg
# count  32.000000
# mean   20.090625
# std     6.026948
# min    10.400000
# 25%    15.425000
# 50%    19.200000
# 75%    22.800000
# max    33.900000

# %%
mpg_matrix = mpg.values.reshape(-1, 1) # reshape into one-column matrix

scaled = preprocessing.MinMaxScaler()

scaled_mpg = scaled.fit_transform(mpg_matrix)
plt.plot(scaled_mpg)

# %%
mpg_matrix = mpg.values.reshape(-1, 1) # reshape into one-column matrix

scaled = preprocessing.MinMaxScaler(feature_range = (0, 10))

scaled_mpg = scaled.fit_transform(mpg_matrix)
plt.plot(scaled_mpg)

# %% [markdown]
# ## Using scale() to scale your features

# %%
standardised_mpg = scale(mpg, axis = 0, with_mean = False, with_std = False)
plt.plot(standardised_mpg)

# %%
standardised_mpg = scale(mpg)
plt.plot(standardised_mpg)
